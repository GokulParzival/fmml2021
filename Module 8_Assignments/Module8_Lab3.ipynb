# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-30 16:47:01--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   151MB/s    in 0.5s
#
# 2022-06-30 16:47:02 (151 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 34266  1501.01318v1  Text categorization is the process of grouping...    cs
# 12268  1711.00765v2  We present an algorithm for approximating a fu...  stat
# 21789  1505.04413v2  In a range of fields including the geosciences...  stat
# 22062   1409.4005v1  This paper studies ordered weighted L1 (OWL) n...  stat
# 4683    1202.5597v3  Bayesian Optimization aims at optimizing an un...    cs
# ...             ...                                                ...   ...
# 5249    1204.2069v4  Hierarchical statistical models are widely emp...  stat
# 8835   1508.01306v2  This report describes an initial replication s...    cs
# 10691   1212.0388v1  Most network-based protein (or gene) function ...  stat
# 1766   1602.02373v2  One-hot CNN (convolutional neural network) has...  stat
# 3303   1501.05684v1  Nonnegative matrix factorization (NMF) is a po...  stat
#
#                                                    title  year  \
# 34266  Arabic Text Categorization Algorithm using Vec...  2015
# 12268  Approximation of Functions over Manifolds: A M...  2017
# 21789         Harmonic Exponential Families on Manifolds  2015
# 22062  Sparse Estimation with Strongly Correlated Var...  2014
# 4683                  Hybrid Batch Bayesian Optimization  2012
# ...                                                  ...   ...
# 5249   Asymptotic Accuracy of Distribution-Based Esti...  2012
# 8835           Replication and Generalization of PRECISE  2015
# 10691  Hypergraph and protein function prediction wit...  2012
# 1766   Supervised and Semi-Supervised Text Categoriza...  2016
# 3303   Bi-Objective Nonnegative Matrix Factorization:...  2015
#
#                                                 keywords
# 34266  [categorization, documents, categories, import...
# 12268  [algorithm, approximating, dimensional, utiliz...
# 21789  [including, geosciences, molecular, encounters...
# 22062  [regularization, estimation, correlated, varia...
# 4683   [optimization, optimizing, convexconcave, inte...
# ...                                                  ...
# 5249   [hierarchical, statistical, information, engin...
# 8835   [describes, replication, description, evaluati...
# 10691  [prediction, assumption, relationship, informa...
# 1766   [effective, categorization, framework, generat...
# 3303   [nonnegative, factorization, extraction, techn...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 34266    [categorization, documents, categories, import...
# 12268    [algorithm, approximating, dimensional, utiliz...
# 21789    [including, geosciences, molecular, encounters...
# 22062    [regularization, estimation, correlated, varia...
# 4683     [optimization, optimizing, convexconcave, inte...
#                                ...
# 6143     [distributed, regularization, reproducing, alg...
# 23609    [recognition, segmentation, procedure, guarant...
# 28423    [localisation, supervised, localisation, discr...
# 10431    [optimization, manifolds, developing, nonlinea...
# 7452     [derivative, optimization, efficient, approxim...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8826 words.
# Out of those 4605 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c9e87a97-719a-43cf-be65-985f6470abb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9e87a97-719a-43cf-be65-985f6470abb3")) {                    Plotly.newPlot(                        "c9e87a97-719a-43cf-be65-985f6470abb3",                        [{"x":["evaluation","calculated","determine","categorized","algorithm","available","classification","promising","information","categorization","categorizes","important","documents","categories","retrieval","researches","presented","reduction","regression","introduces","locations","functions","dimensionality","utilizing","approximating","potential","dimensional","polynomial","numerical","extremely","dimension","regarding","algorithms","furthermore","experiments","distortions","approximation","resistant","knowledge","manifolds","generalization","encounters","densities","commutative","competing","distribution","efficiently","molecular","earthquakes","conjugate","applications","distributions","exponential","modelling","experimental","currently","likelihood","estimation","variables","geosciences","significantly","including","magnitude","probabilistic","transform","correlated","characterize","coefficients","establish","clustering","independent","particular","regardless","measurements","accurately","uncorrelated","statistical","sufficient","different","regularization","conditions","completely","assumptions","generating","performance","generative","significant","systematically","sequential","justification","concurrent","dynamically","suffering","benchmark","advantage","theoretical","application","selection","optimizing","substantial","scenarios","evaluations","specifically","posterior","optimization","estimator","sequentially","interested","alternative","comprises","convolutional","principles","responses","corresponding","learnable","activation","empirically","computational","approximate","theoretically","efficient","parameter","motivated","parameters","demonstrate","activated","experimentally","convolution","naturally","representation","increments","expectation","appropriate","developed","processes","components","corresponds","inference","manifested","construction","shrinkage","variational","compressive","denoising","associated","structure","constructing","heuristic","maximization","framework","multiscale","detection","recognize","functionality","protruding","approaches","intensity","conversation","classified","illumination","traditional","recognition","expressing","assumption","interfacing","intelligence","techniques","reflection","environment","complementary","analyzing","factorization","predicting","outperforms","bootstrap","prediction","criterion","personalized","stochastic","importance","recommender","recommendation","optimized","investigate","implement","equations","development","simplified","discriminant","qualitatively","evolutionary","constituent","computationally","instances","comprising","comprehensively","dominated","objective","selecting","portfolio"],"y":[272,36,63,5,875,288,479,116,644,25,2,362,61,74,104,11,192,88,114,77,38,220,51,40,20,170,179,49,75,46,57,22,610,143,610,13,112,2,333,14,121,2,9,3,25,241,160,9,2,0,438,123,43,42,393,58,63,190,149,0,260,212,62,163,67,29,39,45,41,164,119,284,11,49,69,3,167,74,698,80,126,42,61,86,856,122,250,18,69,10,10,28,2,209,87,148,220,171,48,43,95,63,172,40,347,28,14,23,92,14,349,36,26,133,12,31,69,308,113,42,377,116,41,237,538,2,52,42,56,391,1,29,75,188,97,90,29,220,4,63,7,41,19,51,123,317,48,62,32,557,10,355,38,10,2,422,39,12,29,24,172,353,15,68,4,99,369,6,147,36,56,37,71,273,4,215,66,19,118,99,24,32,50,139,78,24,125,20,10,24,70,10,79,111,12,6,11,141,37,4],"type":"bar"},{"x":["evaluation","calculated","determine","categorized","algorithm","availabl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4605,), (4605, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>a</span> <span style=''>Target</span> <span style=''>Sample</span> <span style=''>Re</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generator</span> <span style=''>for</span> <span style=''>Cross</span> <span style=''>Database</span> <span style=''>Micro</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expression</span> <span style='background-color:rgba(0, 255, 0, 0.5865168539325842);'>Recognition</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>cross</span> <span style=''>database</span> <span style=''>micro</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style='background-color:rgba(0, 255, 0, 0.5865168539325842);'>recognition</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>training</span> <span style=''>and</span> <span style=''>testing</span> <span style=''>samples</span> <span style=''>are</span> <span style=''>from</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>micro</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style='background-color:rgba(0, 255, 0, 0.5064935064935066);'>databases</span> <span style=''>Under</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>the</span> <span style=''>training</span> <span style=''>and</span> <span style=''>testing</span> <span style=''>samples</span> <span style=''>would</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3204419889502762);'>distributions</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>most</span> <span style=''>existing</span> <span style=''>micro</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style='background-color:rgba(0, 255, 0, 0.5865168539325842);'>recognition</span> <span style=''>methods</span> <span style=''>may</span> <span style=''>decrease</span> <span style=''>greatly</span> <span style=''>To</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(0, 255, 0, 0.33689839572192526);'>effective</span> <span style=''>method</span> <span style=''>called</span> <span style=''>Target</span> <span style=''>Sample</span> <span style=''>Re</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generator</span> <span style=''>(TSRG)</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>By</span> <span style=''>using</span> <span style=''>TSRG</span> <span style=''>we</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>re</span> <span style=''>generate</span> <span style=''>the</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>target</span> <span style=''>micro</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style=''>database</span> <span style=''>and</span> <span style=''>the</span> <span style=''>re</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>target</span> <span style=''>samples</span> <span style=''>would</span> <span style=''>share</span> <span style=''>same</span> <span style=''>or</span> <span style=''>similar</span> <span style=''>feature</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Black</span> <span style=''>box</span> <span style=''>α</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Minimization</span> <br/><br/><span style=''>Black</span> <span style=''>box</span> <span style=''>alpha</span> <span style=''>(BB</span> <span style=''>alpha)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>alpha</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergences</span> <span style=''>BB</span> <span style=''>alpha</span> <span style=''>scales</span> <span style=''>to</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>because</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>BB</span> <span style=''>alpha</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>with</span> <span style=''>little</span> <span style=''>effort</span> <span style=''>since</span> <span style=''>it</span> <span style=''>only</span> <span style=''>requires</span> <span style=''>as</span> <span style=''>input</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>function</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>obtained</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiation</span> <span style=''>By</span> <span style=''>changing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>alpha</span> <span style=''>the</span> <span style=''>method</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolate</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayes</span> <span style=''>(VB)</span> <span style=''>(alpha</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rightarrow</span> <span style=''>0)</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>similar</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>(EP)</span> <span style=''>(alpha</span> <span style=''>1)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>probit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style=''>neural</span> <span style=''>network</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Partially</span> <span style=''>Observed</span> <span style=''>Graphs</span> <span style=''>via</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unweighted</span> <span style=''>graph</span> <span style=''>ie</span> <span style=''>one</span> <span style=''>where</span> <span style=''>for</span> <span style=''>some</span> <span style=''>node</span> <span style=''>pairs</span> <span style=''>we</span> <span style=''>know</span> <span style=''>there</span> <span style=''>is</span> <span style=''>an</span> <span style=''>edge</span> <span style=''>between</span> <span style=''>them</span> <span style=''>for</span> <span style=''>some</span> <span style=''>others</span> <span style=''>we</span> <span style=''>know</span> <span style=''>there</span> <span style=''>is</span> <span style=''>no</span> <span style=''>edge</span> <span style=''>and</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3043478260869565);'>remaining</span> <span style=''>we</span> <span style=''>do</span> <span style=''>not</span> <span style=''>know</span> <span style=''>whether</span> <span style=''>or</span> <span style=''>not</span> <span style=''>there</span> <span style=''>is</span> <span style=''>an</span> <span style=''>edge</span> <span style=''>We</span> <span style=''>want</span> <span style=''>to</span> <span style=''>organize</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>into</span> <span style=''>disjoint</span> <span style=''>clusters</span> <span style=''>so</span> <span style=''>that</span> <span style=''>there</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.348314606741573);'>relatively</span> <span style=''>dense</span> <span style=''>(observed)</span> <span style='background-color:rgba(0, 255, 0, 0.3750000000000002);'>connectivity</span> <span style=''>within</span> <span style=''>clusters</span> <span style=''>and</span> <span style=''>sparse</span> <span style=''>across</span> <span style=''>clusters</span> <span style=''>We</span> <span style=''>take</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>yet</span> <span style=''>natural</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>focusing</span> <span style=''>on</span> <span style=''>finding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizes</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>disagreements</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>(observed)</span> <span style=''>missing</span> <span style=''>edges</span> <span style=''>within</span> <span style=''>clusters</span> <span style=''>and</span> <span style=''>(observed)</span> <span style=''>present</span> <span style=''>edges</span> <span style=''>across</span> <span style=''>clusters</span> <span style=''>Our</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Robustness</span> <span style=''>of</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>Among</span> <span style=''>many</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>kernel</span> <span style=''>k</span> <span style=''>means</span> <span style=''>has</span> <span style=''>drawn</span> <span style=''>much</span> <span style=''>research</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>find</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>cluster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>boundaries</span> <span style=''>and</span> <span style=''>its</span> <span style=''>inherent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>There</span> <span style=''>are</span> <span style=''>two</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>k</span> <span style=''>means</span> <span style=''>SVD</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxations</span> <span style=''>Despite</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>has</span> <span style=''>received</span> <span style=''>both</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style=''>applied</span> <span style=''>quarters</span> <span style=''>not</span> <span style=''>much</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semidefinite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxation</span> <span style=''>for</span> <span style=''>the</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>problem</span> <span style=''>then</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>under</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specification</span> <span style=''>both</span> <span style=''>the</span> <span style=''>K</span> <span style=''>SVD</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.23173803526448364)
# 	processing (0.0975170924793091)
# 	architecture (0.08672184238934869)
# 	representation (0.14069809283915077)
# 	segmentation (0.07880532565671104)
# 	different (0.2511694854264124)
# 	experimental (0.14141777617848147)
# 	detection (0.12774379273119826)
# 	recognition (0.1270241093918676)
# 	convolutional (0.1255847427132062)
#
# Some Statistics words are:
# 	convergence (0.12271152894606631)
# 	stochastic (0.12370113805047006)
# 	statistical (0.1504205838693716)
# 	distribution (0.1781296387926769)
# 	variables (0.14794656110836218)
# 	theoretical (0.15388421573478475)
# 	estimation (0.17466600692726372)
# 	inference (0.19693221177634834)
# 	dimensional (0.1855517070757051)
# 	regression (0.1781296387926769)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f38059e8-f51f-408a-928b-ea6bdbc13f4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f38059e8-f51f-408a-928b-ea6bdbc13f4d")) {                    Plotly.newPlot(                        "f38059e8-f51f-408a-928b-ea6bdbc13f4d",                        [{"x":["evaluation","calculated","determine","categorized","algorithm","available","classification","promising","information","categorization","categorizes","important","documents","categories","retrieval","researches","presented","reduction","regression","introduces","locations","functions","dimensionality","utilizing","approximating","potential","dimensional","polynomial","numerical","extremely","dimension","regarding","algorithms","furthermore","experiments","distortions","approximation","resistant","knowledge","manifolds","generalization","encounters","densities","commutative","competing","distribution","efficiently","molecular","earthquakes","conjugate","applications","distributions","exponential","modelling","experimental","currently","likelihood","estimation","variables","geosciences","significantly","including","magnitude","probabilistic","transform","correlated","characterize","coefficients","establish","clustering","independent","particular","regardless","measurements","accurately","uncorrelated","statistical","sufficient","different","regularization","conditions","completely","assumptions","generating","performance","generative","significant","systematically","sequential","justification","concurrent","dynamically","suffering","benchmark","advantage","theoretical","application","selection","optimizing","substantial","scenarios","evaluations","specifically","posterior","optimization","estimator","sequentially","interested","alternative","comprises","convolutional","principles","responses","corresponding","learnable","activation","empirically","computational","approximate","theoretically","efficient","parameter","motivated","parameters","demonstrate","activated","experimentally","convolution","naturally","representation","increments","expectation","appropriate","developed","processes","components","corresponds","inference","manifested","construction","shrinkage","variational","compressive","denoising","associated","structure","constructing","heuristic","maximization","framework","multiscale","detection","recognize","functionality","protruding","approaches","intensity","conversation","classified","illumination","traditional","recognition","expressing","assumption","interfacing","intelligence","techniques","reflection","environment","complementary","analyzing","factorization","predicting","outperforms","bootstrap","prediction","criterion","personalized","stochastic","importance","recommender","recommendation","optimized","investigate","implement","equations","development","simplified","discriminant","qualitatively","evolutionary","constituent","computationally","instances","comprising","comprehensively","dominated","objective","selecting","portfolio","harnesses","specialized","treatment","sensitive","extracted","performances","alignment","coordinate","appearance","previously","verification","robustness","processing","surpasses","differential","published","benchmarks","resulting","intermediate","calibration","learnability","situations","describing","approachability","algorithmic","sridharan","forecasters","convergence","martingale","extending","simultaneously","complexity","quantities","rademacher","challenge","automatic","represent","hypothesis","recurrent","confusion","architecture","architectures","connected","increasing","technique","randomized","constrained","approximates","fundamental","environments","operation","sketching","substantially","effective","comparable","dimensions","re ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	conjugate
# 	geosciences
# 	sridharan
# 	martingale
# 	marginally
# 	popularly
# 	ultrahigh
# 	reconcile
# 	procrustes
# 	semiparametric
# 	inferential
# 	downweighting
# 	neuroscientists
# 	lengthscale
# 	approachable
# 	staleness
# 	bhattacharya
# 	emphsparse
# 	penalization
# 	accumulating
# Some words which never appear in Statistics papers:
# 	categorized
# 	categorizes
# 	protruding
# 	reflection
# 	disparity
# 	repetitive
# 	compliance
# 	continued
# 	propositional
# 	literally
# 	photographic
# 	recognizers
# 	occlusions
# 	accelerators
# 	inadequacy
# 	localizing
# 	appending
# 	transformer
# 	connectionist
# 	conversational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0868961259453624e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
